# %%
from datasets_fetching.UCI_ML_Functions import download_datasets_task

# %%
download_datasets_task(task='Classification', local_database='../datasets_fetching/UCI database.csv', local_table='../datasets_fetching/UCI table.csv', msg_flag=True)
# Out:
# Number of datasets found: 221
# ...
# 404 FOUND
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from implementations import standard_neural_network
from matplotlib import pyplot as plt

# %% [markdown]
# # Dataset Loading

# %%
dataset = pd.read_csv('/Users/vincenzopecorella/Desktop/Universita/Machine Learning/Project2/datasets/creditcard.csv')
dataset_y = dataset.Class
dataset_X = dataset.drop(columns=['Class'])


X_train, X_test, y_train, y_test = train_test_split(dataset_X, dataset_y, test_size=0.33, random_state=42)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Number of Points Feature

# %%
dataset.shape

# %% [markdown]
# Feature Distribution

# %%
def draw_histograms(dataframe, features, rows, cols):
    fig=plt.figure(figsize=(20,20))
    for i, feature in enumerate(features):
        ax=fig.add_subplot(rows,cols,i+1)
        dataframe[feature].hist(bins=20,ax=ax,facecolor='midnightblue')
        ax.set_title(feature+" Distribution",color='DarkRed')
        ax.set_yscale('log')
    fig.tight_layout()
    plt.show()
draw_histograms(dataset,dataset.columns,8,4)

# %% [markdown]
# # STD Neural Network

# %%
standard_neural_network(x_training_set=X_train, x_test_set=X_test, y_training_set=y_train, y_test_set=y_test,  hidden_layer_size=(30, 30))
# Out:
# [except] GPU not found. Standard TDP=250 assigned.
# accuracy is: 0.8848138572355752
# ########
# Overall carbon footprint: 6.66e-01 gCO2eq
# ########
# Carbon footprint due to computations: 6.66e-01 gCO2eq
# Carbon footprint due to communications: 0.00e+00 gCO2eq
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-38bc91f1f755> in <module>
# ----> 1 standard_neural_network(x_training_set=X_train, x_test_set=X_test, y_training_set=y_train, y_test_set=y_test,  hidden_layer_size=(30, 30))
#
# ~/Desktop/Universita/Machine Learning/Project2/implementations.py in standard_neural_network(x_training_set, y_training_set, x_test_set, y_test_set, classification, hidden_layer_size, activation, solver)
#      17
#      18     print("accuracy is: " + str(accuracy))
# ---> 19     cumulator.display_carbon_footprint()
#
# ...
